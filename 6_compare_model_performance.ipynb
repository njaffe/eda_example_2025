# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
comparison_df = pd.read_csv('model_comparison.csv')

# %%
comparison_df
# Out:
#                 Model            R2     Train_MAE    Train_RMSE       Val_MAE  \
# 0      LR_single_feat  6.582905e-01  33366.620987  47588.821126  3.433189e+04
# 1         LR_all_feat  8.129140e-01  23604.571316  36245.825551  2.347266e+04
# 2      LR_top_20_feat  8.324828e-01  21663.030622  34243.914882  2.169396e+04
# 3        LR_Quadratic  8.420397e-01  21674.186381  34055.259913  2.139558e+04
# 4   Linear Regression -1.585056e+23  14642.822406  22869.362333  1.132837e+15
# 5    Ridge Regression -6.613171e-03  59115.910476  80734.082759  5.727649e+04
# 6  RidgeCV Regression  9.028154e-01  15791.085652  25308.508695  1.561811e+04
# 7       Decision Tree  7.838586e-01      0.000000      0.000000  2.397668e+04
# 8             XGBoost  8.955728e-01   9884.642412  13242.761300  1.637279e+04
# 9            CatBoost  8.615313e-01  11467.671011  15828.443752  1.848040e+04
#
#        Val_RMSE
# 0  4.901043e+04
# 1  3.626441e+04
# 2  3.431545e+04
# 3  3.332222e+04
# 4  3.067040e+16
# ...
