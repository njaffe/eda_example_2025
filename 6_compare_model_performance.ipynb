# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
comparison_df = pd.read_csv('model_comparison.csv')

# %%
comparison_df
# Out:
#                  Model     Train MAE    Train RMSE  Validation MAE  \
# 0              Model 1  33366.620987  47588.821126    34331.889385
# 1              Model 2  23604.571316  36245.825551    23472.656831
# 2              Model 3  21663.030622  34243.914882    21693.955732
# 3              Model 4           NaN           NaN             NaN
# 4              Model 5           NaN           NaN             NaN
# 5              Model 6           NaN           NaN             NaN
# 6              Model 7           NaN           NaN             NaN
# 7              Model 8           NaN           NaN             NaN
# 8    Linear Regression           NaN           NaN             NaN
# 9     Ridge Regression           NaN           NaN             NaN
# 10  RidgeCV Regression           NaN           NaN             NaN
# 11       Decision Tree           NaN           NaN             NaN
# 12             XGBoost           NaN           NaN             NaN
# ...
